# %%
pip install python-pptx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 7.0 MB/s eta 0:00:00
# ...

# %%
import pptx
from pptx import Presentation
from pptx.util import Inches, Pt,Cm
from pptx.enum.text import PP_ALIGN
from pptx.util import Pt
from pptx.dml.color import RGBColor
from pptx.enum.shapes import MSO_SHAPE

prs = Presentation()


# first slide
blank_slide_layout = prs.slide_layouts[6]
slide1 = prs.slides.add_slide(blank_slide_layout)


# background picture
img_path1 = "bg.png"
left = Inches(0)
top = Inches(0)
bg = slide1.shapes.add_picture(img_path1, left, top)


# company picture
img_path2 = "comp_name.png"
bg = slide1.shapes.add_picture(img_path2, Inches(0.6), Inches(0.6))


# paytm picture
img_path3 = "paytm.png"
paytm = slide1.shapes.add_picture(img_path3, Inches(8.3), Inches(0.6))


# look beyond picture
img_path4 = "text.png"
paytm = slide1.shapes.add_picture(img_path4, Inches(0.35), Inches(6.6))


# heading
heading = slide1.shapes.add_textbox(Inches(0.5), Inches(3), Inches(8), Inches(4))
tf = heading.text_frame
tf.text = "Recommended List"


# heading properties
paragraph = tf.paragraphs[0]
paragraph.font.name = 'Arial Black'
paragraph.font.size = pptx.util.Pt(43.5)
paragraph.font.bold = True
paragraph.font.color.rgb = pptx.dml.color.RGBColor(255, 255, 255)


# sub heading
heading = slide1.shapes.add_textbox(Inches(0.5), Inches(3.7), Inches(8), Inches(4))
tf = heading.text_frame
tf.text = "Chief Controls Officer"


# sub heading properties
paragraph = tf.paragraphs[0]
paragraph.font.name = 'Arial'
paragraph.font.size = pptx.util.Pt(17.5)
paragraph.font.color.rgb = pptx.dml.color.RGBColor(255, 255, 255)


# second slide
blank_slide_layout = prs.slide_layouts[6]
slide2 = prs.slides.add_slide(blank_slide_layout)


# format to set position
# textbox_labels = slide2.shapes.add_textbox(left, top, width, height)


# heading
heading = slide2.shapes.add_textbox(Cm(5), Cm(1), Cm(15), Cm(1))
tf = heading.text_frame
tf.text = "KETAN JAIN"
heading.text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER


# heading properties
paragraph = tf.paragraphs[0]
paragraph.font.name = 'Arial Black'
paragraph.font.size = pptx.util.Pt(24)
paragraph.font.color.rgb = pptx.dml.color.RGBColor(128, 0, 128)


# profile picture
img_path1 = "profile.png"
left = Inches(0.5)
top = Inches(0.1)
profile = slide2.shapes.add_picture(img_path1, left, top)


# company picture
img_path2 = "company.png"
left = Inches(8.5)
top = Inches(0.1)
company = slide2.shapes.add_picture(img_path2, left, top)

# footer picture
img_path3 = "footer.png"
left = Inches(0)
top = Inches(6.9)
footer = slide2.shapes.add_picture(img_path3, left, top)


# textbox frame left
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(1.2), Inches(4.4), Inches(5.5))
textbox.line.color.rgb = RGBColor(0, 0, 0)
textbox.line.width = Pt(1)


# basic info labels
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(0.9), Inches(4.4), Inches(1))
tf = textbox.text_frame

text_content = [
    "Age:",
    "Location:",
    "Nationality:"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = True
    p.alignment = PP_ALIGN.LEFT
    p.font.color.rgb = pptx.dml.color.RGBColor(128, 0, 128)


# basic info values
textbox = slide2.shapes.add_textbox(Inches(1.5), Inches(0.9), Inches(4.4), Inches(1))
tf = textbox.text_frame

text_content = [
    "45",
    "Mumbai",
    "Indian"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.LEFT


# education heading
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(1.7), Inches(4.4), Inches(1))
tf = textbox.text_frame

text_content = [
    "EDUCATION:"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = True
    p.alignment = PP_ALIGN.LEFT
    p.font.color.rgb = pptx.dml.color.RGBColor(128, 0, 128)


# education year values - add a wrap limit
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(1.9), Inches(4.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True

text_content = [
    "2006:",
    "2004:"
    ]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.LEFT


# education institute values
textbox = slide2.shapes.add_textbox(Inches(1.5), Inches(1.9), Inches(3.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True

text_content = [
    "Chartered Accountant, ICAI",
    "B.Com, Lala Lajpat Rai College Of Commerce & Economics, Mumbai University"
    ]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.LEFT


# experience heading
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(2.7), Inches(4.4), Inches(1))
tf = textbox.text_frame

text_content = [
    "PROFESSIONAL EXPERIENCE:"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = True
    p.alignment = PP_ALIGN.LEFT
    p.font.color.rgb = pptx.dml.color.RGBColor(128, 0, 128)


# experience values
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(2.9), Inches(4.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True
wrap_limit = 49

exp_info = [
      "MARICO LTD, Mumbai",
      "Head Finance – Corporate & International Business",
      "Head – Strategy and Digital Businesses (Finance & Operations)",
      "Head Commercial -  Sales & Marketing",
      "Head – Strategic Business Planning and M&A",
      "Head Finance Transformation (South East Asia Operations), Vietnam",
      "GRC & Project Manager",
      "Finance Manager",
      "PRICE WATERHOUSE COOPERS, Mumbai Associate"
    ]

wrap_index = []
for i in range(len(exp_info)):
  if len(exp_info[i])>wrap_limit:
    wrap_index.append(i)


# text_content = [
#       "2007 - Till Date:    MARICO LTD, Mumbai",
#       "2023 - Till Date     Head Finance – Corporate & International Business",
#       "2022 - 2023          Head – Strategy and Digital Businesses (Finance & Operations)",
#       "2019 - 2022          Head Commercial -  Sales & Marketing",
#       "2016 - 2019          Head – Strategic Business Planning and M&A",
#       "2014 - 2016          Head Finance Transformation (South East Asia Operations), Vietnam",
#       "2012 - 2014          GRC & Project Manager",
#       "2007 - 2012          Finance Manager",
#       "2006 - 2007          PRICE WATERHOUSE COOPERS, Mumbai Associate"
#     ]

# for text_line in text_content:
#     p = tf.add_paragraph()
#     p.text = text_line
#     p.font.size = Pt(10)
#     p.font.name = 'Calibri'
#     p.font.bold = False
#     p.alignment = PP_ALIGN.LEFT


# experience year values
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(2.9), Inches(4.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True

text_content = [
      "2007 - Till Date",
      "2023 - Till Date",
      "2022 - 2023",
      "2019 - 2022",
      "2016 - 2019",
      "2014 - 2016",
      "2012 - 2014",
      "2007 - 2012",
      "2006 - 2007"
    ]

temp = 0
for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.LEFT

    if temp in wrap_index:
      p = tf.add_paragraph()
      p.text = ''
      p.font.size = Pt(10)
      p.font.name = 'Calibri'
      p.font.bold = False
      p.alignment = PP_ALIGN.LEFT

    temp += 1

# experience company values
textbox = slide2.shapes.add_textbox(Inches(1.5), Inches(2.9), Inches(3.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True

text_content = [
      "MARICO LTD, Mumbai",
      "Head Finance – Corporate & International Business",
      "Head – Strategy and Digital Businesses (Finance & Operations)",
      "Head Commercial -  Sales & Marketing",
      "Head – Strategic Business Planning and M&A",
      "Head Finance Transformation (South East Asia Operations), Vietnam",
      "GRC & Project Manager",
      "Finance Manager",
      "PRICE WATERHOUSE COOPERS, Mumbai Associate"
    ]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.LEFT


# compensation box
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(6.2), Inches(4.4), Inches(0.25))
textbox.fill.solid()
textbox.fill.fore_color.rgb = RGBColor(128, 0, 128)

# compensation text
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(5.9), Inches(4.4), Inches(0.25))
tf = textbox.text_frame

text_content = [
    "COMPENSATION"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(11)
    p.font.name = 'Calibri'
    p.font.bold = True
    p.alignment = PP_ALIGN.CENTER
    p.font.color.rgb = pptx.dml.color.RGBColor(255, 255, 255)

# salary box
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(6.45), Inches(4.4), Inches(0.25))
textbox.fill.solid()
textbox.fill.fore_color.rgb = RGBColor(255, 0, 0)

# salary text
textbox = slide2.shapes.add_textbox(Inches(0.5), Inches(6.15), Inches(4.4), Inches(0.25))
tf = textbox.text_frame

text_content = [
    "~INR xx LPA fixed + xx Lakhs variable + ESOPS"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(11)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.CENTER
    p.font.color.rgb = pptx.dml.color.RGBColor(255, 255, 255)


# textbox frame right
textbox = slide2.shapes.add_textbox(Inches(5.1), Inches(1.2), Inches(4.4), Inches(5.5))
textbox.line.color.rgb = RGBColor(0, 0, 0)
textbox.line.width = Pt(1)


# highlights heading
textbox = slide2.shapes.add_textbox(Inches(5.1), Inches(0.9), Inches(4.4), Inches(1))
tf = textbox.text_frame

text_content = [
    "KEY HIGHLIGHTS:"
]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = text_line
    p.font.size = Pt(11)
    p.font.name = 'Calibri'
    p.font.bold = True
    p.alignment = PP_ALIGN.LEFT
    p.font.color.rgb = pptx.dml.color.RGBColor(128, 0, 128)


# highlight values
textbox = slide2.shapes.add_textbox(Inches(5.1), Inches(1.1), Inches(4.4), Inches(1))
tf = textbox.text_frame
tf.word_wrap = True


text_content = [
  'Ketan comes with over 17 years of total experience in roles spanning finance, operations and strategy.',
  'He has been associated with Marico since 2007. He joined the organisation as a Finance Manager and grew consistently to take charge of his current role as Head – Finance, Corporate and International Business. In this capacity, he is looking at both FP&A and controllership, how subsidiaries are working, cost optimisation, sales control. He also looks after corporate accounting, treasury and is responsible for devising business strategies and execution plan along with the CEO.',
  # 'Prior to this, he was the Head – Strategy and Digital Business (Finance and Operations). Here, he collaborated to debottleneck challenges for execution of key business strategies. He managed relationship with promoters of invested companies and business CEOs (Invested Companies: Just Herbs, True elements/ Business CEOs: Beardo, Puresense, Cocosoul, Fittity).',
  'In the past, he played a variety of roles such as Head – Commercial – Sales and Marketing, as well as Head – Strategy, Business Planning and M&A, responsible for driving and facilitate the development of Strategic Business Plan and Integrated strategy for SBU’s with relevant cross-functional stakeholder. He was accountable for assessing and supporting key strategic initiatives for new growth engines and entry into the newer market.',
  'As Head – Finance Transformation, South East Asia Operations, Ketan was  steering the preparation of long-term plans, annual operating plans and rolling quarter forecasts. He partnered with the business for product pricing, trade & consumer promotions, capital expenditures approval, new product feasibility. Provide decision-making support & insightful MIS to Management committee. He ensured a control environment for the recording of transactions, period end closing including finalization of Annual Accounts, statutory audit, and tax audit. Ketan also spearheaded the Performance management system involving gross margin monitoring, compliance for advertising and overhead budgeting, tracking peer companies, CAPEM monitoring and review to analyze business level ROCE and EVA.',
  'He commenced his career with PWC as an Associate and handled a range of statutory and tax audits for FMCG and retail sector.'
]

# content_slide = slide.placeholders[1]

for text_line in text_content:
    p = tf.add_paragraph()
    p.text = '• ' + text_line
    p.font.size = Pt(10)
    p.font.name = 'Calibri'
    p.font.bold = False
    p.alignment = PP_ALIGN.JUSTIFY
    p.level = 0
    # p.space_after = Pt(18)


# Iterate over the list and add each item as a paragraph with a bullet point
# for item in my_list:
#     p = content_slide.text_frame.add_paragraph()
#     p.text = item
#     p.level = 0  # Setting the bullet level to 0 to indicate a top-level bullet point
#     p.space_after = Pt(18)  # Adding some space after each paragraph


prs.save('test.pptx')
print('done')
# Out:
# done
